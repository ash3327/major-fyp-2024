# %% [markdown]
# # Visualize Keypoints

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

# %%
# Load your dataset
data = pd.read_csv("augmented_hand_landmarks.csv")

# Extract features (landmark coordinates) and labels
X = data.drop(columns=['label']).values  # Only coordinates
y = data['label'].values  # Labels

# %%
_X = np.array(X).reshape(-1, 20, 3)
print(_X.shape)
print(np.max(_X[:,:,0]), np.min(_X[:,:,0]))
print(np.max(_X[:,:,1]), np.min(_X[:,:,1]))
print(np.max(_X[:,:,2]), np.min(_X[:,:,2]))
# Out:
# (731745, 20, 3)
# 0.6923749400535836 -0.6930017082713996
# 0.3592362373274168 -0.817860180760111
# 0.5067949898239582 -0.7024156541080712

# %%
import matplotlib.pyplot as plt
import numpy as np

sample = np.array(X[100]).reshape(20, 3) 

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(sample[:, 0], sample[:, 1], sample[:, 2], c=range(20), cmap='viridis', s=4)

ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_zlim(-1, 1) 

plt.show()
